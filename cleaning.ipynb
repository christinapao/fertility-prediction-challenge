# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('PreFer_train_data.csv')
outcome = pd.read_csv('PreFer_train_outcome.csv')
# Out:
# C:\Users\liric\AppData\Local\Temp\ipykernel_3548\1572285469.py:1: DtypeWarning: Columns (2583,2584,2585,2586,2587,2588,2589,4358,4359,4360,4361,4362,4363,4364,4365,4366,4367,4368,4369,4370,4371,4372,4373,4374,4375,4379,4380,4381,4382,4383,4384,4385,4386,4387,4388,4389,4390,4391,4392,4393,4394,4395,4396,4397,4398,4399,4400,4401,4405,4406,4407,4408,4409,5215,5216,5219,5220,5613,5614,5615,5616,5617,5618,5619,5620,5621,5622,5624,5625,5626,5627,5628,5629,5630,5631,5632,5633,5634,5635,5636,5638,5639,5640,5787,5788,5789,5790,5791,5792,5793,5794,5795,5796,6393,6394,6395,6396,6397,6398,6399,6400,6401,6402,6403,6619,6620,6621,6622,6623,6624,6625,6626,6627,6628,6629,6630,6631,6632,6633,6634,6635,6638,6640,6641,6642,6643,6644,6645,6646,6647,6648,6649,6650,6651,6652,6653,6654,6655,6656,6657,6658,6659,6660,6661,6664,6666,6667,6668,6669,6670,6965,6966,6967,6968,6969,6970,6971,6972,6973,6974,6975,7064,7065,7066,7067,7068,7069,7070,7071,7072,7073,7074,7163,7164,7165,7166,7167,7168,7169,7170,7171,7172
# ...

# %%
train = train[train['outcome_available'] == 1]
outcome = outcome.dropna()
train = pd.merge(train, outcome, on = 'nomem_encr')
train_drop = train.dropna(axis = 1, thresh = len(train)/2)

# %%
# fill all empty entries with -1, no filtering
train_min1 = train.fillna(-1)
# drop all columns missing more than half of data, fill all empty with -1
train_DropMin1 = train_drop.fillna(-1)
# fill all empty entries by setting equal to last observed value (or next observed if no last observed)
train_last = train.bfill(axis = 1).ffill(axis = 1)
# drop all columns missing more thna half of data, fill empty entries by setting equal to last observed value (or next observed if no last observed)
train_droplast = train_drop.bfill(axis = 1).ffill(axis = 1)
# Out:
# C:\Users\liric\AppData\Local\Temp\ipykernel_3548\1129861809.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_min1 = train.fillna(-1)
# C:\Users\liric\AppData\Local\Temp\ipykernel_3548\1129861809.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_last = train.bfill(axis = 1).ffill(axis = 1)
# ...
